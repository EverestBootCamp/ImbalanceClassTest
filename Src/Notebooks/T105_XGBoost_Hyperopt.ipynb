# %% [markdown]
# ###### This notebook presents an implementaion of XGBoost Classifier in Imabalanced data .After building the XGBoost Classifier it will use the HyperOpt Library to tune the various model parameters with the goal of achieving the maximum f1-score for Classes.

# %% [markdown]
# #### Loading Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import log_loss
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
from hyperopt import space_eval
import xgboost as xgb

# %%
class XGBModel():
    """
      A class to represent XGboost and Hyperopt.

    """

    def __init__(
            self,
            train_path,
            test_path,
            num_boost_round=50,
            early_stopping_rounds=10,
            CV=5,
            label='Class'):
        """
        This method takes the input parameters, performs scaling
        """
        train = pd.read_csv(train_path)  # reading train data
        test = pd.read_csv(test_path)  # reading test data
        # remove :1000 during production
        self.X_train = train.iloc[:1000, :-1]
        self.X_test = test.iloc[:1000, :-1]
        self.y_train = train.iloc[:1000, :][label]
        self.y_test = test.iloc[:1000, :][label]
        sc = StandardScaler()  # scaling data
        self.scaled_X_train = sc.fit_transform(self.X_train)
        self.scaled_X_test = sc.transform(self.X_test)
        self.dtrain = xgb.DMatrix(self.scaled_X_train, label=self.y_train)
        self.dtest = xgb.DMatrix(self.scaled_X_test, label=self.y_test)
        label = self.dtrain.get_label()
        self.ratio = float(np.sum(label == 0)) / np.sum(label == 1)
        self.num_boost_round = num_boost_round
        self.early_stopping_rounds = early_stopping_rounds
        self.CV = CV

    # Define the function to minimize (XGboost Model)
    def optimize_hyperparam(self, n_eval=25):
        """
        This method is performing hyperparameter tuning using HyperOpt
        for XGboost
        ...
        parameters
        ----------
        In hyperopt bayesian optimization can be implemented giving three main
        parameters to the function fmin.
        Objective: Defines the loss function to minimize.
        space    : Defines the range of input values to test.
        Algo     : defines the search algorithm to select the best input values to
        use in each iteration.
        """
        #defining function to optimize
        def objective(space4xgb):
            """
            This method defines objective function to be tuned by the HyperOpt

            """
            model = xgb.train(
                space4xgb,
                self.dtrain,
                num_boost_round=self.num_boost_round,
                evals=[
                    (self.dtrain,
                     'train'),
                    (self.dtest,
                     'validation')],
                early_stopping_rounds=self.early_stopping_rounds)
            pred = model.predict(self.dtest)
            score = log_loss(self.y_test, pred)
            print("\tScore {0}\n\n".format(score))
            return {'loss': score, 'status': STATUS_OK}

        # Defining the space for hyperparameter tuning.

        def hyper_params():
            """
            hp.choice(label, options) — Returns one of the options, which should be a list or tuple.
            hp.randint(label, upper) — Returns a random integer between the range [0, upper).
            hp.uniform(label, low, high) — Returns a value uniformly between low and high.
            hp.quniform(label, low, high, q) — Returns a value round(uniform(low, high) / q) * q,
            i.e it rounds the decimal values and returns an integer.
            hp.normal(label, mean, std) — Returns a real value that’s normally-distributed with
            mean and standard deviation sigma.
            """
            space4xgb = {
                'objective': 'binary:logistic',
                'eval_metric': 'logloss',
                'booster': 'gbtree',
                'verbosity': 1,
                'disable_default_eval_metric': 1,
                'reg_lambda': hp.quniform('reg_lambda', 1, 2, 0.1),
                'reg_alpha': hp.quniform('reg_alpha', 0, 10, 1),
                'max_delta_step': hp.quniform('max_delta_step', 1, 10, 1),
                'max_depth': hp.choice('max_depth', np.arange(1, 14,
                                                              dtype=int)),
                'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
                'gamma': hp.quniform('gamma', 0.5, 1.0, 0.05),
                'sampling_method': 'uniform',
                'min_child_weight': hp.quniform('min_child_weight',
                                                1, 10, 1),
                'colsample_bytree': hp.quniform('colsample_bytree',
                                                0.5, 1, 0.05),
                'colsample_bylevel': hp.quniform('colsample_bylevel',
                                                 0.5, 1, 0.05),
                'colsample_bynode': hp.quniform('colsample_bynode',
                                                0.5, 1, 0.05),
                'scale_pos_weight': self.ratio

            }

            return space4xgb
        space4xgb = hyper_params()

        # Initialize trials object.
        trials = Trials()
        # using seed to get repeatable results.
        seed = 123
        # run the hyper paramter tuning.
        best = fmin(fn=objective,
                    space=space4xgb,
                    algo=tpe.suggest,
                    max_evals=n_eval,
                    trials=trials,
                    rstate=np.random.RandomState(seed))
        print(space_eval(space4xgb, best))
        hyperparams = space_eval(space4xgb, best)
        return hyperparams

# %%
model = XGBModel("data_transformed.csv", "data_transformed.csv")

model.optimize_hyperparam()
# Out:
# [0]	train-logloss:0.55897	validation-logloss:0.55897
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.46088	validation-logloss:0.46088
#
# [2]	train-logloss:0.38431	validation-logloss:0.38431
#
# [3]	train-logloss:0.32469	validation-logloss:0.32469
#
# [4]	train-logloss:0.27788	validation-logloss:0.27788
#
# [5]	train-logloss:0.23622	validation-logloss:0.23622
#
# [6]	train-logloss:0.20275	validation-logloss:0.20275
#
# [7]	train-logloss:0.17649	validation-logloss:0.17649
#
# [8]	train-logloss:0.15203	validation-logloss:0.15203
#
# [9]	train-logloss:0.13142	validation-logloss:0.13142
#
# [10]	train-logloss:0.11470	validation-logloss:0.11470
#
# [11]	train-logloss:0.10033	validation-logloss:0.10033
#
# [12]	train-logloss:0.08817	validation-logloss:0.08817
#
# [13]	train-logloss:0.07788	validation-logloss:0.07788
#
# [14]	train-logloss:0.06872	validation-logloss:0.06872
#
# [15]	train-logloss:0.06113	validation-logloss:0.06113
#
# [16]	train-logloss:0.05456	validation-logloss:0.05456
#
# [17]	train-logloss:0.04879	validation-logloss:0.04879
#
# [18]	train-logloss:0.04410	validation-logloss:0.04410
#
# [19]	train-logloss:0.03988	validation-logloss:0.03988
#
# [20]	train-logloss:0.03657	validation-logloss:0.03657
#
# [21]	train-logloss:0.03386	validation-logloss:0.03386
#
# [22]	train-logloss:0.03040	validation-logloss:0.03040
#
# [23]	train-logloss:0.02796	validation-logloss:0.02796
#
# [24]	train-logloss:0.02590	validation-logloss:0.02590
#
# [25]	train-logloss:0.02446	validation-logloss:0.02446
#
# [26]	train-logloss:0.02279	validation-logloss:0.02279
#
# [27]	train-logloss:0.02175	validation-logloss:0.02175
#
# [28]	train-logloss:0.02005	validation-logloss:0.02005
#
# [29]	train-logloss:0.01878	validation-logloss:0.01878
#
# [30]	train-logloss:0.01823	validation-logloss:0.01823
#
# [31]	train-logloss:0.01727	validation-logloss:0.01727
#
# [32]	train-logloss:0.01642	validation-logloss:0.01642
#
# [33]	train-logloss:0.01570	validation-logloss:0.01570
#
# [34]	train-logloss:0.01570	validation-logloss:0.01570
#
# [35]	train-logloss:0.01503	validation-logloss:0.01503
#
# [36]	train-logloss:0.01447	validation-logloss:0.01447
#
# [37]	train-logloss:0.01425	validation-logloss:0.01425
#
# [38]	train-logloss:0.01405	validation-logloss:0.01405
#
# [39]	train-logloss:0.01359	validation-logloss:0.01359
#
# [40]	train-logloss:0.01336	validation-logloss:0.01336
#
# [41]	train-logloss:0.01297	validation-logloss:0.01297
#
# [42]	train-logloss:0.01297	validation-logloss:0.01297
#
# [43]	train-logloss:0.01257	validation-logloss:0.01257
#
# [44]	train-logloss:0.01194	validation-logloss:0.01194
#
# [45]	train-logloss:0.01194	validation-logloss:0.01194
#
# [46]	train-logloss:0.01194	validation-logloss:0.01194
#
# [47]	train-logloss:0.01165	validation-logloss:0.01165
#
# [48]	train-logloss:0.01165	validation-logloss:0.01165
#
# [49]	train-logloss:0.01165	validation-logloss:0.01165
#
# 	Score 0.011654052806086838
#
#
# [0]	train-logloss:0.57919	validation-logloss:0.57919
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.49052	validation-logloss:0.49052
#
# [2]	train-logloss:0.42121	validation-logloss:0.42121
#
# [3]	train-logloss:0.36202	validation-logloss:0.36202
#
# [4]	train-logloss:0.31325	validation-logloss:0.31325
#
# [5]	train-logloss:0.27245	validation-logloss:0.27245
#
# [6]	train-logloss:0.23748	validation-logloss:0.23748
#
# [7]	train-logloss:0.20777	validation-logloss:0.20777
#
# [8]	train-logloss:0.18427	validation-logloss:0.18427
#
# [9]	train-logloss:0.16216	validation-logloss:0.16216
#
# [10]	train-logloss:0.14375	validation-logloss:0.14375
#
# [11]	train-logloss:0.12735	validation-logloss:0.12735
#
# [12]	train-logloss:0.11382	validation-logloss:0.11382
#
# [13]	train-logloss:0.10116	validation-logloss:0.10116
#
# [14]	train-logloss:0.09023	validation-logloss:0.09023
#
# [15]	train-logloss:0.08065	validation-logloss:0.08065
#
# [16]	train-logloss:0.07307	validation-logloss:0.07307
#
# [17]	train-logloss:0.06647	validation-logloss:0.06647
#
# [18]	train-logloss:0.05989	validation-logloss:0.05989
#
# [19]	train-logloss:0.05411	validation-logloss:0.05411
#
# [20]	train-logloss:0.04866	validation-logloss:0.04866
#
# [21]	train-logloss:0.04378	validation-logloss:0.04378
#
# [22]	train-logloss:0.03989	validation-logloss:0.03989
#
# [23]	train-logloss:0.03628	validation-logloss:0.03628
#
# [24]	train-logloss:0.03338	validation-logloss:0.03338
#
# [25]	train-logloss:0.03073	validation-logloss:0.03073
#
# [26]	train-logloss:0.02844	validation-logloss:0.02844
#
# [27]	train-logloss:0.02641	validation-logloss:0.02641
#
# [28]	train-logloss:0.02444	validation-logloss:0.02444
#
# [29]	train-logloss:0.02286	validation-logloss:0.02286
#
# [30]	train-logloss:0.02144	validation-logloss:0.02144
#
# [31]	train-logloss:0.02021	validation-logloss:0.02021
#
# [32]	train-logloss:0.01908	validation-logloss:0.01908
#
# [33]	train-logloss:0.01810	validation-logloss:0.01810
#
# [34]	train-logloss:0.01720	validation-logloss:0.01720
#
# [35]	train-logloss:0.01642	validation-logloss:0.01642
#
# [36]	train-logloss:0.01570	validation-logloss:0.01570
#
# [37]	train-logloss:0.01507	validation-logloss:0.01507
#
# [38]	train-logloss:0.01452	validation-logloss:0.01452
#
# [39]	train-logloss:0.01404	validation-logloss:0.01404
#
# [40]	train-logloss:0.01362	validation-logloss:0.01362
#
# [41]	train-logloss:0.01314	validation-logloss:0.01314
#
# [42]	train-logloss:0.01278	validation-logloss:0.01278
#
# [43]	train-logloss:0.01238	validation-logloss:0.01238
#
# [44]	train-logloss:0.01170	validation-logloss:0.01170
#
# [45]	train-logloss:0.01140	validation-logloss:0.01140
#
# [46]	train-logloss:0.01114	validation-logloss:0.01114
#
# [47]	train-logloss:0.01090	validation-logloss:0.01090
#
# [48]	train-logloss:0.01070	validation-logloss:0.01070
#
# [49]	train-logloss:0.01051	validation-logloss:0.01051
#
# 	Score 0.010505848534405232
#
#
# [0]	train-logloss:0.46690	validation-logloss:0.46690
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.31506	validation-logloss:0.31506
#
# [2]	train-logloss:0.23525	validation-logloss:0.23525
#
# [3]	train-logloss:0.16904	validation-logloss:0.16904
#
# [4]	train-logloss:0.12575	validation-logloss:0.12575
#
# [5]	train-logloss:0.09565	validation-logloss:0.09565
#
# [6]	train-logloss:0.07496	validation-logloss:0.07496
#
# [7]	train-logloss:0.06001	validation-logloss:0.06001
#
# [8]	train-logloss:0.04686	validation-logloss:0.04686
#
# [9]	train-logloss:0.03947	validation-logloss:0.03947
#
# [10]	train-logloss:0.03445	validation-logloss:0.03445
#
# [11]	train-logloss:0.03104	validation-logloss:0.03104
#
# [12]	train-logloss:0.02777	validation-logloss:0.02777
#
# [13]	train-logloss:0.02523	validation-logloss:0.02523
#
# [14]	train-logloss:0.02340	validation-logloss:0.02340
#
# [15]	train-logloss:0.02110	validation-logloss:0.02110
#
# [16]	train-logloss:0.02002	validation-logloss:0.02002
#
# [17]	train-logloss:0.01816	validation-logloss:0.01816
#
# [18]	train-logloss:0.01685	validation-logloss:0.01685
#
# [19]	train-logloss:0.01685	validation-logloss:0.01685
#
# [20]	train-logloss:0.01685	validation-logloss:0.01685
#
# [21]	train-logloss:0.01685	validation-logloss:0.01685
#
# [22]	train-logloss:0.01685	validation-logloss:0.01685
#
# [23]	train-logloss:0.01603	validation-logloss:0.01603
#
# [24]	train-logloss:0.01603	validation-logloss:0.01603
#
# [25]	train-logloss:0.01544	validation-logloss:0.01544
#
# [26]	train-logloss:0.01544	validation-logloss:0.01544
#
# [27]	train-logloss:0.01544	validation-logloss:0.01544
#
# [28]	train-logloss:0.01544	validation-logloss:0.01544
#
# [29]	train-logloss:0.01544	validation-logloss:0.01544
#
# [30]	train-logloss:0.01544	validation-logloss:0.01544
#
# [31]	train-logloss:0.01544	validation-logloss:0.01544
#
# [32]	train-logloss:0.01544	validation-logloss:0.01544
#
# [33]	train-logloss:0.01544	validation-logloss:0.01544
#
# [34]	train-logloss:0.01544	validation-logloss:0.01544
#
# [35]	train-logloss:0.01544	validation-logloss:0.01544
#
# Stopping. Best iteration:
# [25]	train-logloss:0.01544	validation-logloss:0.01544
#
#
# 	Score 0.015437179622240364
#
#
# [0]	train-logloss:0.51931	validation-logloss:0.51931
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.40277	validation-logloss:0.40277
#
# [2]	train-logloss:0.32162	validation-logloss:0.32162
#
# [3]	train-logloss:0.25681	validation-logloss:0.25681
#
# [4]	train-logloss:0.20761	validation-logloss:0.20761
#
# [5]	train-logloss:0.16970	validation-logloss:0.16970
#
# [6]	train-logloss:0.13972	validation-logloss:0.13972
#
# [7]	train-logloss:0.11634	validation-logloss:0.11634
#
# [8]	train-logloss:0.09952	validation-logloss:0.09952
#
# [9]	train-logloss:0.08381	validation-logloss:0.08381
#
# [10]	train-logloss:0.07083	validation-logloss:0.07083
#
# [11]	train-logloss:0.06016	validation-logloss:0.06016
#
# [12]	train-logloss:0.05139	validation-logloss:0.05139
#
# [13]	train-logloss:0.04429	validation-logloss:0.04429
#
# [14]	train-logloss:0.03860	validation-logloss:0.03860
#
# [15]	train-logloss:0.03417	validation-logloss:0.03417
#
# [16]	train-logloss:0.03063	validation-logloss:0.03063
#
# [17]	train-logloss:0.02724	validation-logloss:0.02724
#
# [18]	train-logloss:0.02562	validation-logloss:0.02562
#
# [19]	train-logloss:0.02267	validation-logloss:0.02267
#
# [20]	train-logloss:0.02159	validation-logloss:0.02159
#
# [21]	train-logloss:0.02074	validation-logloss:0.02074
#
# [22]	train-logloss:0.01991	validation-logloss:0.01991
#
# [23]	train-logloss:0.01850	validation-logloss:0.01850
#
# [24]	train-logloss:0.01684	validation-logloss:0.01684
#
# [25]	train-logloss:0.01590	validation-logloss:0.01590
#
# [26]	train-logloss:0.01486	validation-logloss:0.01486
#
# [27]	train-logloss:0.01463	validation-logloss:0.01463
#
# [28]	train-logloss:0.01398	validation-logloss:0.01398
#
# [29]	train-logloss:0.01385	validation-logloss:0.01385
#
# [30]	train-logloss:0.01331	validation-logloss:0.01331
#
# [31]	train-logloss:0.01331	validation-logloss:0.01331
#
# [32]	train-logloss:0.01331	validation-logloss:0.01331
#
# [33]	train-logloss:0.01331	validation-logloss:0.01331
#
# [34]	train-logloss:0.01331	validation-logloss:0.01331
#
# [35]	train-logloss:0.01331	validation-logloss:0.01331
#
# [36]	train-logloss:0.01331	validation-logloss:0.01331
#
# [37]	train-logloss:0.01250	validation-logloss:0.01250
#
# [38]	train-logloss:0.01250	validation-logloss:0.01250
#
# [39]	train-logloss:0.01250	validation-logloss:0.01250
#
# [40]	train-logloss:0.01245	validation-logloss:0.01245
#
# [41]	train-logloss:0.01245	validation-logloss:0.01245
#
# [42]	train-logloss:0.01245	validation-logloss:0.01245
#
# [43]	train-logloss:0.01245	validation-logloss:0.01245
#
# [44]	train-logloss:0.01176	validation-logloss:0.01176
#
# [45]	train-logloss:0.01176	validation-logloss:0.01176
#
# [46]	train-logloss:0.01176	validation-logloss:0.01176
#
# [47]	train-logloss:0.01176	validation-logloss:0.01176
#
# [48]	train-logloss:0.01176	validation-logloss:0.01176
#
# [49]	train-logloss:0.01176	validation-logloss:0.01176
#
# 	Score 0.011764576775021851
#
#
# [0]	train-logloss:0.37273	validation-logloss:0.37273
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.23614	validation-logloss:0.23614
#
# [2]	train-logloss:0.15565	validation-logloss:0.15565
#
# [3]	train-logloss:0.11254	validation-logloss:0.11254
#
# [4]	train-logloss:0.07664	validation-logloss:0.07664
#
# [5]	train-logloss:0.05937	validation-logloss:0.05937
#
# [6]	train-logloss:0.04792	validation-logloss:0.04792
#
# [7]	train-logloss:0.03475	validation-logloss:0.03475
#
# [8]	train-logloss:0.02636	validation-logloss:0.02636
#
# [9]	train-logloss:0.02135	validation-logloss:0.02135
#
# [10]	train-logloss:0.01726	validation-logloss:0.01726
#
# [11]	train-logloss:0.01528	validation-logloss:0.01528
#
# [12]	train-logloss:0.01308	validation-logloss:0.01308
#
# [13]	train-logloss:0.01170	validation-logloss:0.01170
#
# [14]	train-logloss:0.01081	validation-logloss:0.01081
#
# [15]	train-logloss:0.01081	validation-logloss:0.01081
#
# [16]	train-logloss:0.00967	validation-logloss:0.00967
#
# [17]	train-logloss:0.00967	validation-logloss:0.00967
#
# [18]	train-logloss:0.00967	validation-logloss:0.00967
#
# [19]	train-logloss:0.00967	validation-logloss:0.00967
#
# [20]	train-logloss:0.00967	validation-logloss:0.00967
#
# [21]	train-logloss:0.00967	validation-logloss:0.00967
#
# [22]	train-logloss:0.00967	validation-logloss:0.00967
#
# [23]	train-logloss:0.00967	validation-logloss:0.00967
#
# [24]	train-logloss:0.00967	validation-logloss:0.00967
#
# [25]	train-logloss:0.00967	validation-logloss:0.00967
#
# [26]	train-logloss:0.00967	validation-logloss:0.00967
#
# Stopping. Best iteration:
# [16]	train-logloss:0.00967	validation-logloss:0.00967
#
#
# 	Score 0.009673100335989147
#
#
# [0]	train-logloss:0.38179	validation-logloss:0.38179
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.23652	validation-logloss:0.23652
#
# [2]	train-logloss:0.16007	validation-logloss:0.16007
#
# [3]	train-logloss:0.10933	validation-logloss:0.10933
#
# [4]	train-logloss:0.07609	validation-logloss:0.07609
#
# [5]	train-logloss:0.05412	validation-logloss:0.05412
#
# [6]	train-logloss:0.03952	validation-logloss:0.03952
#
# [7]	train-logloss:0.03000	validation-logloss:0.03000
#
# [8]	train-logloss:0.02308	validation-logloss:0.02308
#
# [9]	train-logloss:0.01996	validation-logloss:0.01996
#
# [10]	train-logloss:0.01687	validation-logloss:0.01687
#
# [11]	train-logloss:0.01387	validation-logloss:0.01387
#
# [12]	train-logloss:0.01308	validation-logloss:0.01308
#
# [13]	train-logloss:0.01189	validation-logloss:0.01189
#
# [14]	train-logloss:0.01040	validation-logloss:0.01040
#
# [15]	train-logloss:0.00924	validation-logloss:0.00924
#
# [16]	train-logloss:0.00924	validation-logloss:0.00924
#
# [17]	train-logloss:0.00924	validation-logloss:0.00924
#
# [18]	train-logloss:0.00924	validation-logloss:0.00924
#
# [19]	train-logloss:0.00924	validation-logloss:0.00924
#
# [20]	train-logloss:0.00837	validation-logloss:0.00837
#
# [21]	train-logloss:0.00837	validation-logloss:0.00837
#
# [22]	train-logloss:0.00837	validation-logloss:0.00837
#
# [23]	train-logloss:0.00837	validation-logloss:0.00837
#
# [24]	train-logloss:0.00789	validation-logloss:0.00789
#
# [25]	train-logloss:0.00789	validation-logloss:0.00789
#
# [26]	train-logloss:0.00789	validation-logloss:0.00789
#
# [27]	train-logloss:0.00789	validation-logloss:0.00789
#
# [28]	train-logloss:0.00789	validation-logloss:0.00789
#
# [29]	train-logloss:0.00789	validation-logloss:0.00789
#
# [30]	train-logloss:0.00793	validation-logloss:0.00793
#
# [31]	train-logloss:0.00793	validation-logloss:0.00793
#
# [32]	train-logloss:0.00793	validation-logloss:0.00793
#
# [33]	train-logloss:0.00793	validation-logloss:0.00793
#
# [34]	train-logloss:0.00793	validation-logloss:0.00793
#
# Stopping. Best iteration:
# [24]	train-logloss:0.00789	validation-logloss:0.00789
#
#
# 	Score 0.00792716261302121
#
#
# [0]	train-logloss:0.45055	validation-logloss:0.45055
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.31772	validation-logloss:0.31772
#
# [2]	train-logloss:0.22908	validation-logloss:0.22908
#
# [3]	train-logloss:0.17088	validation-logloss:0.17088
#
# [4]	train-logloss:0.12929	validation-logloss:0.12929
#
# [5]	train-logloss:0.10129	validation-logloss:0.10129
#
# [6]	train-logloss:0.08048	validation-logloss:0.08048
#
# [7]	train-logloss:0.06588	validation-logloss:0.06588
#
# [8]	train-logloss:0.05453	validation-logloss:0.05453
#
# [9]	train-logloss:0.04659	validation-logloss:0.04659
#
# [10]	train-logloss:0.04008	validation-logloss:0.04008
#
# [11]	train-logloss:0.03232	validation-logloss:0.03232
#
# [12]	train-logloss:0.02921	validation-logloss:0.02921
#
# [13]	train-logloss:0.02641	validation-logloss:0.02641
#
# [14]	train-logloss:0.02445	validation-logloss:0.02445
#
# [15]	train-logloss:0.02229	validation-logloss:0.02229
#
# [16]	train-logloss:0.02091	validation-logloss:0.02091
#
# [17]	train-logloss:0.01954	validation-logloss:0.01954
#
# [18]	train-logloss:0.01861	validation-logloss:0.01861
#
# [19]	train-logloss:0.01784	validation-logloss:0.01784
#
# [20]	train-logloss:0.01728	validation-logloss:0.01728
#
# [21]	train-logloss:0.01675	validation-logloss:0.01675
#
# [22]	train-logloss:0.01536	validation-logloss:0.01536
#
# [23]	train-logloss:0.01431	validation-logloss:0.01431
#
# [24]	train-logloss:0.01431	validation-logloss:0.01431
#
# [25]	train-logloss:0.01431	validation-logloss:0.01431
#
# [26]	train-logloss:0.01431	validation-logloss:0.01431
#
# [27]	train-logloss:0.01431	validation-logloss:0.01431
#
# [28]	train-logloss:0.01431	validation-logloss:0.01431
#
# [29]	train-logloss:0.01431	validation-logloss:0.01431
#
# [30]	train-logloss:0.01431	validation-logloss:0.01431
#
# [31]	train-logloss:0.01431	validation-logloss:0.01431
#
# [32]	train-logloss:0.01431	validation-logloss:0.01431
#
# [33]	train-logloss:0.01431	validation-logloss:0.01431
#
# Stopping. Best iteration:
# [23]	train-logloss:0.01431	validation-logloss:0.01431
#
#
# 	Score 0.014305002429522574
#
#
# [0]	train-logloss:0.40734	validation-logloss:0.40734
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.26134	validation-logloss:0.26134
#
# [2]	train-logloss:0.17878	validation-logloss:0.17878
#
# [3]	train-logloss:0.12908	validation-logloss:0.12908
#
# [4]	train-logloss:0.09841	validation-logloss:0.09841
#
# [5]	train-logloss:0.07365	validation-logloss:0.07365
#
# [6]	train-logloss:0.06072	validation-logloss:0.06072
#
# [7]	train-logloss:0.05007	validation-logloss:0.05007
#
# [8]	train-logloss:0.03998	validation-logloss:0.03998
#
# [9]	train-logloss:0.03487	validation-logloss:0.03487
#
# [10]	train-logloss:0.03066	validation-logloss:0.03066
#
# [11]	train-logloss:0.02599	validation-logloss:0.02599
#
# [12]	train-logloss:0.02170	validation-logloss:0.02170
#
# [13]	train-logloss:0.01968	validation-logloss:0.01968
#
# [14]	train-logloss:0.01889	validation-logloss:0.01889
#
# [15]	train-logloss:0.01802	validation-logloss:0.01802
#
# [16]	train-logloss:0.01737	validation-logloss:0.01737
#
# [17]	train-logloss:0.01737	validation-logloss:0.01737
#
# [18]	train-logloss:0.01737	validation-logloss:0.01737
#
# [19]	train-logloss:0.01737	validation-logloss:0.01737
#
# [20]	train-logloss:0.01737	validation-logloss:0.01737
#
# [21]	train-logloss:0.01737	validation-logloss:0.01737
#
# [22]	train-logloss:0.01737	validation-logloss:0.01737
#
# [23]	train-logloss:0.01737	validation-logloss:0.01737
#
# [24]	train-logloss:0.01737	validation-logloss:0.01737
#
# [25]	train-logloss:0.01737	validation-logloss:0.01737
#
# [26]	train-logloss:0.01737	validation-logloss:0.01737
#
# Stopping. Best iteration:
# [16]	train-logloss:0.01737	validation-logloss:0.01737
#
#
# 	Score 0.017367081667063758
#
#
# [0]	train-logloss:0.39086	validation-logloss:0.39086
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.32175	validation-logloss:0.32175
#
# [2]	train-logloss:0.25169	validation-logloss:0.25169
#
# [3]	train-logloss:0.19932	validation-logloss:0.19932
#
# [4]	train-logloss:0.13954	validation-logloss:0.13954
#
# [5]	train-logloss:0.11775	validation-logloss:0.11775
#
# [6]	train-logloss:0.08986	validation-logloss:0.08986
#
# [7]	train-logloss:0.07694	validation-logloss:0.07694
#
# [8]	train-logloss:0.06347	validation-logloss:0.06347
#
# [9]	train-logloss:0.05511	validation-logloss:0.05511
#
# [10]	train-logloss:0.04783	validation-logloss:0.04783
#
# [11]	train-logloss:0.04193	validation-logloss:0.04193
#
# [12]	train-logloss:0.03657	validation-logloss:0.03657
#
# [13]	train-logloss:0.03133	validation-logloss:0.03133
#
# [14]	train-logloss:0.02286	validation-logloss:0.02286
#
# [15]	train-logloss:0.02031	validation-logloss:0.02031
#
# [16]	train-logloss:0.01774	validation-logloss:0.01774
#
# [17]	train-logloss:0.01555	validation-logloss:0.01555
#
# [18]	train-logloss:0.01213	validation-logloss:0.01213
#
# [19]	train-logloss:0.01127	validation-logloss:0.01127
#
# [20]	train-logloss:0.01052	validation-logloss:0.01052
#
# [21]	train-logloss:0.00972	validation-logloss:0.00972
#
# [22]	train-logloss:0.00898	validation-logloss:0.00898
#
# [23]	train-logloss:0.00752	validation-logloss:0.00752
#
# [24]	train-logloss:0.00752	validation-logloss:0.00752
#
# [25]	train-logloss:0.00656	validation-logloss:0.00656
#
# [26]	train-logloss:0.00656	validation-logloss:0.00656
#
# [27]	train-logloss:0.00593	validation-logloss:0.00593
#
# [28]	train-logloss:0.00593	validation-logloss:0.00593
#
# [29]	train-logloss:0.00549	validation-logloss:0.00549
#
# [30]	train-logloss:0.00549	validation-logloss:0.00549
#
# [31]	train-logloss:0.00549	validation-logloss:0.00549
#
# [32]	train-logloss:0.00549	validation-logloss:0.00549
#
# [33]	train-logloss:0.00549	validation-logloss:0.00549
#
# [34]	train-logloss:0.00549	validation-logloss:0.00549
#
# [35]	train-logloss:0.00549	validation-logloss:0.00549
#
# [36]	train-logloss:0.00549	validation-logloss:0.00549
#
# [37]	train-logloss:0.00549	validation-logloss:0.00549
#
# [38]	train-logloss:0.00549	validation-logloss:0.00549
#
# [39]	train-logloss:0.00549	validation-logloss:0.00549
#
# Stopping. Best iteration:
# [29]	train-logloss:0.00549	validation-logloss:0.00549
#
#
# 	Score 0.005493339561318862
#
#
# [0]	train-logloss:0.33378	validation-logloss:0.33378
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.20167	validation-logloss:0.20167
#
# [2]	train-logloss:0.13590	validation-logloss:0.13590
#
# [3]	train-logloss:0.08585	validation-logloss:0.08585
#
# [4]	train-logloss:0.05791	validation-logloss:0.05791
#
# [5]	train-logloss:0.04561	validation-logloss:0.04561
#
# [6]	train-logloss:0.03657	validation-logloss:0.03657
#
# [7]	train-logloss:0.03047	validation-logloss:0.03047
#
# [8]	train-logloss:0.02168	validation-logloss:0.02168
#
# [9]	train-logloss:0.01784	validation-logloss:0.01784
#
# [10]	train-logloss:0.01727	validation-logloss:0.01727
#
# [11]	train-logloss:0.01659	validation-logloss:0.01659
#
# [12]	train-logloss:0.01659	validation-logloss:0.01659
#
# [13]	train-logloss:0.01659	validation-logloss:0.01659
#
# [14]	train-logloss:0.01659	validation-logloss:0.01659
#
# [15]	train-logloss:0.01659	validation-logloss:0.01659
#
# [16]	train-logloss:0.01659	validation-logloss:0.01659
#
# [17]	train-logloss:0.01659	validation-logloss:0.01659
#
# [18]	train-logloss:0.01659	validation-logloss:0.01659
#
# [19]	train-logloss:0.01659	validation-logloss:0.01659
#
# [20]	train-logloss:0.01659	validation-logloss:0.01659
#
# [21]	train-logloss:0.01659	validation-logloss:0.01659
#
# Stopping. Best iteration:
# [11]	train-logloss:0.01659	validation-logloss:0.01659
#
#
# 	Score 0.016588316151872277
#
#
# [0]	train-logloss:0.64767	validation-logloss:0.64767
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.60615	validation-logloss:0.60615
#
# [2]	train-logloss:0.57031	validation-logloss:0.57031
#
# [3]	train-logloss:0.53571	validation-logloss:0.53571
#
# [4]	train-logloss:0.50338	validation-logloss:0.50338
#
# [5]	train-logloss:0.47342	validation-logloss:0.47342
#
# [6]	train-logloss:0.44578	validation-logloss:0.44578
#
# [7]	train-logloss:0.42051	validation-logloss:0.42051
#
# [8]	train-logloss:0.39697	validation-logloss:0.39697
#
# [9]	train-logloss:0.37485	validation-logloss:0.37485
#
# [10]	train-logloss:0.35492	validation-logloss:0.35492
#
# [11]	train-logloss:0.33618	validation-logloss:0.33618
#
# [12]	train-logloss:0.31848	validation-logloss:0.31848
#
# [13]	train-logloss:0.30232	validation-logloss:0.30232
#
# [14]	train-logloss:0.28674	validation-logloss:0.28674
#
# [15]	train-logloss:0.27216	validation-logloss:0.27216
#
# [16]	train-logloss:0.25991	validation-logloss:0.25991
#
# [17]	train-logloss:0.24767	validation-logloss:0.24767
#
# [18]	train-logloss:0.23526	validation-logloss:0.23526
#
# [19]	train-logloss:0.22416	validation-logloss:0.22416
#
# [20]	train-logloss:0.21313	validation-logloss:0.21313
#
# [21]	train-logloss:0.20463	validation-logloss:0.20463
#
# [22]	train-logloss:0.19490	validation-logloss:0.19490
#
# [23]	train-logloss:0.18566	validation-logloss:0.18566
#
# [24]	train-logloss:0.17745	validation-logloss:0.17745
#
# [25]	train-logloss:0.16914	validation-logloss:0.16914
#
# [26]	train-logloss:0.16170	validation-logloss:0.16170
#
# [27]	train-logloss:0.15428	validation-logloss:0.15428
#
# [28]	train-logloss:0.14729	validation-logloss:0.14729
#
# [29]	train-logloss:0.14071	validation-logloss:0.14071
#
# [30]	train-logloss:0.13453	validation-logloss:0.13453
#
# [31]	train-logloss:0.12846	validation-logloss:0.12846
#
# [32]	train-logloss:0.12375	validation-logloss:0.12375
#
# [33]	train-logloss:0.11838	validation-logloss:0.11838
#
# [34]	train-logloss:0.11377	validation-logloss:0.11377
#
# [35]	train-logloss:0.10919	validation-logloss:0.10919
#
# [36]	train-logloss:0.10505	validation-logloss:0.10505
#
# [37]	train-logloss:0.10147	validation-logloss:0.10147
#
# [38]	train-logloss:0.09754	validation-logloss:0.09754
#
# [39]	train-logloss:0.09416	validation-logloss:0.09416
#
# [40]	train-logloss:0.09045	validation-logloss:0.09045
#
# [41]	train-logloss:0.08759	validation-logloss:0.08759
#
# [42]	train-logloss:0.08425	validation-logloss:0.08425
#
# [43]	train-logloss:0.08089	validation-logloss:0.08089
#
# [44]	train-logloss:0.07795	validation-logloss:0.07795
#
# [45]	train-logloss:0.07531	validation-logloss:0.07531
#
# [46]	train-logloss:0.07295	validation-logloss:0.07295
#
# [47]	train-logloss:0.07015	validation-logloss:0.07015
#
# [48]	train-logloss:0.06810	validation-logloss:0.06810
#
# [49]	train-logloss:0.06579	validation-logloss:0.06579
#
# 	Score 0.06579090934991837
#
#
# [0]	train-logloss:0.48074	validation-logloss:0.48074
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.35055	validation-logloss:0.35055
#
# [2]	train-logloss:0.26608	validation-logloss:0.26608
#
# [3]	train-logloss:0.20302	validation-logloss:0.20302
#
# [4]	train-logloss:0.15701	validation-logloss:0.15701
#
# [5]	train-logloss:0.12268	validation-logloss:0.12268
#
# [6]	train-logloss:0.09667	validation-logloss:0.09667
#
# [7]	train-logloss:0.07676	validation-logloss:0.07676
#
# [8]	train-logloss:0.06438	validation-logloss:0.06438
#
# [9]	train-logloss:0.05322	validation-logloss:0.05322
#
# [10]	train-logloss:0.04460	validation-logloss:0.04460
#
# [11]	train-logloss:0.03678	validation-logloss:0.03678
#
# [12]	train-logloss:0.03237	validation-logloss:0.03237
#
# [13]	train-logloss:0.02694	validation-logloss:0.02694
#
# [14]	train-logloss:0.02289	validation-logloss:0.02289
#
# [15]	train-logloss:0.01970	validation-logloss:0.01970
#
# [16]	train-logloss:0.01725	validation-logloss:0.01725
#
# [17]	train-logloss:0.01523	validation-logloss:0.01523
#
# [18]	train-logloss:0.01373	validation-logloss:0.01373
#
# [19]	train-logloss:0.01323	validation-logloss:0.01323
#
# [20]	train-logloss:0.01206	validation-logloss:0.01206
#
# [21]	train-logloss:0.01206	validation-logloss:0.01206
#
# [22]	train-logloss:0.01179	validation-logloss:0.01179
#
# [23]	train-logloss:0.01098	validation-logloss:0.01098
#
# [24]	train-logloss:0.01033	validation-logloss:0.01033
#
# [25]	train-logloss:0.00982	validation-logloss:0.00982
#
# [26]	train-logloss:0.00982	validation-logloss:0.00982
#
# [27]	train-logloss:0.00982	validation-logloss:0.00982
#
# [28]	train-logloss:0.00982	validation-logloss:0.00982
#
# [29]	train-logloss:0.00982	validation-logloss:0.00982
#
# [30]	train-logloss:0.00982	validation-logloss:0.00982
#
# [31]	train-logloss:0.00982	validation-logloss:0.00982
#
# [32]	train-logloss:0.00982	validation-logloss:0.00982
#
# [33]	train-logloss:0.00982	validation-logloss:0.00982
#
# [34]	train-logloss:0.00918	validation-logloss:0.00918
#
# [35]	train-logloss:0.00918	validation-logloss:0.00918
#
# [36]	train-logloss:0.00918	validation-logloss:0.00918
#
# [37]	train-logloss:0.00918	validation-logloss:0.00918
#
# [38]	train-logloss:0.00918	validation-logloss:0.00918
#
# [39]	train-logloss:0.00918	validation-logloss:0.00918
#
# [40]	train-logloss:0.00918	validation-logloss:0.00918
#
# [41]	train-logloss:0.00918	validation-logloss:0.00918
#
# [42]	train-logloss:0.00918	validation-logloss:0.00918
#
# [43]	train-logloss:0.00918	validation-logloss:0.00918
#
# [44]	train-logloss:0.00918	validation-logloss:0.00918
#
# Stopping. Best iteration:
# [34]	train-logloss:0.00918	validation-logloss:0.00918
#
#
# 	Score 0.00918064228259027
#
#
# [0]	train-logloss:0.56163	validation-logloss:0.56163
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.46433	validation-logloss:0.46433
#
# [2]	train-logloss:0.39276	validation-logloss:0.39276
#
# [3]	train-logloss:0.33090	validation-logloss:0.33090
#
# [4]	train-logloss:0.28158	validation-logloss:0.28158
#
# [5]	train-logloss:0.24134	validation-logloss:0.24134
#
# [6]	train-logloss:0.20820	validation-logloss:0.20820
#
# [7]	train-logloss:0.17962	validation-logloss:0.17962
#
# [8]	train-logloss:0.15524	validation-logloss:0.15524
#
# [9]	train-logloss:0.13567	validation-logloss:0.13567
#
# [10]	train-logloss:0.11924	validation-logloss:0.11924
#
# [11]	train-logloss:0.10545	validation-logloss:0.10545
#
# [12]	train-logloss:0.09251	validation-logloss:0.09251
#
# [13]	train-logloss:0.08221	validation-logloss:0.08221
#
# [14]	train-logloss:0.07337	validation-logloss:0.07337
#
# [15]	train-logloss:0.06500	validation-logloss:0.06500
#
# [16]	train-logloss:0.05867	validation-logloss:0.05867
#
# [17]	train-logloss:0.05354	validation-logloss:0.05354
#
# [18]	train-logloss:0.04858	validation-logloss:0.04858
#
# [19]	train-logloss:0.04442	validation-logloss:0.04442
#
# [20]	train-logloss:0.04072	validation-logloss:0.04072
#
# [21]	train-logloss:0.03869	validation-logloss:0.03869
#
# [22]	train-logloss:0.03617	validation-logloss:0.03617
#
# [23]	train-logloss:0.03356	validation-logloss:0.03356
#
# [24]	train-logloss:0.03136	validation-logloss:0.03136
#
# [25]	train-logloss:0.02950	validation-logloss:0.02950
#
# [26]	train-logloss:0.02737	validation-logloss:0.02737
#
# [27]	train-logloss:0.02601	validation-logloss:0.02601
#
# [28]	train-logloss:0.02507	validation-logloss:0.02507
#
# [29]	train-logloss:0.02335	validation-logloss:0.02335
#
# [30]	train-logloss:0.02243	validation-logloss:0.02243
#
# [31]	train-logloss:0.02186	validation-logloss:0.02186
#
# [32]	train-logloss:0.02137	validation-logloss:0.02137
#
# [33]	train-logloss:0.02035	validation-logloss:0.02035
#
# [34]	train-logloss:0.01996	validation-logloss:0.01996
#
# [35]	train-logloss:0.01913	validation-logloss:0.01913
#
# [36]	train-logloss:0.01913	validation-logloss:0.01913
#
# [37]	train-logloss:0.01843	validation-logloss:0.01843
#
# [38]	train-logloss:0.01843	validation-logloss:0.01843
#
# [39]	train-logloss:0.01784	validation-logloss:0.01784
#
# [40]	train-logloss:0.01784	validation-logloss:0.01784
#
# [41]	train-logloss:0.01742	validation-logloss:0.01742
#
# [42]	train-logloss:0.01742	validation-logloss:0.01742
#
# [43]	train-logloss:0.01695	validation-logloss:0.01695
#
# [44]	train-logloss:0.01606	validation-logloss:0.01606
#
# [45]	train-logloss:0.01529	validation-logloss:0.01529
#
# [46]	train-logloss:0.01505	validation-logloss:0.01505
#
# [47]	train-logloss:0.01505	validation-logloss:0.01505
#
# [48]	train-logloss:0.01505	validation-logloss:0.01505
#
# [49]	train-logloss:0.01449	validation-logloss:0.01449
#
# 	Score 0.014488744569942355
#
#
# [0]	train-logloss:0.40580	validation-logloss:0.40580
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.25114	validation-logloss:0.25114
#
# [2]	train-logloss:0.17064	validation-logloss:0.17064
#
# [3]	train-logloss:0.11494	validation-logloss:0.11494
#
# [4]	train-logloss:0.07767	validation-logloss:0.07767
#
# [5]	train-logloss:0.05479	validation-logloss:0.05479
#
# [6]	train-logloss:0.04000	validation-logloss:0.04000
#
# [7]	train-logloss:0.02971	validation-logloss:0.02971
#
# [8]	train-logloss:0.02182	validation-logloss:0.02182
#
# [9]	train-logloss:0.01675	validation-logloss:0.01675
#
# [10]	train-logloss:0.01372	validation-logloss:0.01372
#
# [11]	train-logloss:0.01187	validation-logloss:0.01187
#
# [12]	train-logloss:0.01044	validation-logloss:0.01044
#
# [13]	train-logloss:0.00948	validation-logloss:0.00948
#
# [14]	train-logloss:0.00888	validation-logloss:0.00888
#
# ...
#
# [15]	train-logloss:0.00962	validation-logloss:0.00962
#
# [16]	train-logloss:0.00857	validation-logloss:0.00857
#
# [17]	train-logloss:0.00768	validation-logloss:0.00768
#
# [18]	train-logloss:0.00674	validation-logloss:0.00674
#
# [19]	train-logloss:0.00594	validation-logloss:0.00594
#
# [20]	train-logloss:0.00528	validation-logloss:0.00528
#
# [21]	train-logloss:0.00487	validation-logloss:0.00487
#
# [22]	train-logloss:0.00453	validation-logloss:0.00453
#
# [23]	train-logloss:0.00453	validation-logloss:0.00453
#
# [24]	train-logloss:0.00453	validation-logloss:0.00453
#
# [25]	train-logloss:0.00453	validation-logloss:0.00453
#
# [26]	train-logloss:0.00453	validation-logloss:0.00453
#
# [27]	train-logloss:0.00453	validation-logloss:0.00453
#
# [28]	train-logloss:0.00453	validation-logloss:0.00453
#
# [29]	train-logloss:0.00453	validation-logloss:0.00453
#
# [30]	train-logloss:0.00453	validation-logloss:0.00453
#
# [31]	train-logloss:0.00453	validation-logloss:0.00453
#
# [32]	train-logloss:0.00453	validation-logloss:0.00453
#
# Stopping. Best iteration:
# [22]	train-logloss:0.00453	validation-logloss:0.00453
#
#
# 	Score 0.004527466239982459
#
#
# [0]	train-logloss:0.35676	validation-logloss:0.35676
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.27989	validation-logloss:0.27989
#
# [2]	train-logloss:0.17059	validation-logloss:0.17059
#
# [3]	train-logloss:0.11478	validation-logloss:0.11478
#
# [4]	train-logloss:0.09414	validation-logloss:0.09414
#
# [5]	train-logloss:0.06451	validation-logloss:0.06451
#
# [6]	train-logloss:0.04933	validation-logloss:0.04933
#
# [7]	train-logloss:0.04100	validation-logloss:0.04100
#
# [8]	train-logloss:0.03021	validation-logloss:0.03021
#
# [9]	train-logloss:0.02482	validation-logloss:0.02482
#
# [10]	train-logloss:0.01981	validation-logloss:0.01981
#
# [11]	train-logloss:0.01585	validation-logloss:0.01585
#
# [12]	train-logloss:0.01352	validation-logloss:0.01352
#
# [13]	train-logloss:0.01138	validation-logloss:0.01138
#
# [14]	train-logloss:0.00964	validation-logloss:0.00964
#
# [15]	train-logloss:0.00821	validation-logloss:0.00821
#
# [16]	train-logloss:0.00716	validation-logloss:0.00716
#
# [17]	train-logloss:0.00628	validation-logloss:0.00628
#
# [18]	train-logloss:0.00531	validation-logloss:0.00531
#
# [19]	train-logloss:0.00447	validation-logloss:0.00447
#
# [20]	train-logloss:0.00376	validation-logloss:0.00376
#
# [21]	train-logloss:0.00340	validation-logloss:0.00340
#
# [22]	train-logloss:0.00310	validation-logloss:0.00310
#
# [23]	train-logloss:0.00283	validation-logloss:0.00283
#
# [24]	train-logloss:0.00249	validation-logloss:0.00249
#
# [25]	train-logloss:0.00217	validation-logloss:0.00217
#
# [26]	train-logloss:0.00205	validation-logloss:0.00205
#
# [27]	train-logloss:0.00202	validation-logloss:0.00202
#
# [28]	train-logloss:0.00200	validation-logloss:0.00200
#
# [29]	train-logloss:0.00198	validation-logloss:0.00198
#
# [30]	train-logloss:0.00197	validation-logloss:0.00197
#
# [31]	train-logloss:0.00179	validation-logloss:0.00179
#
# [32]	train-logloss:0.00178	validation-logloss:0.00178
#
# [33]	train-logloss:0.00178	validation-logloss:0.00178
#
# [34]	train-logloss:0.00178	validation-logloss:0.00178
#
# [35]	train-logloss:0.00178	validation-logloss:0.00178
#
# [36]	train-logloss:0.00178	validation-logloss:0.00178
#
# [37]	train-logloss:0.00178	validation-logloss:0.00178
#
# [38]	train-logloss:0.00178	validation-logloss:0.00178
#
# [39]	train-logloss:0.00178	validation-logloss:0.00178
#
# [40]	train-logloss:0.00178	validation-logloss:0.00178
#
# [41]	train-logloss:0.00178	validation-logloss:0.00178
#
# [42]	train-logloss:0.00178	validation-logloss:0.00178
#
# [43]	train-logloss:0.00178	validation-logloss:0.00178
#
# [44]	train-logloss:0.00178	validation-logloss:0.00178
#
# [45]	train-logloss:0.00178	validation-logloss:0.00178
#
# [46]	train-logloss:0.00178	validation-logloss:0.00178
#
# [47]	train-logloss:0.00178	validation-logloss:0.00178
#
# [48]	train-logloss:0.00178	validation-logloss:0.00178
#
# [49]	train-logloss:0.00178	validation-logloss:0.00178
#
# Stopping. Best iteration:
# [39]	train-logloss:0.00178	validation-logloss:0.00178
#
#
# 	Score 0.001774610280059278
#
#
# [0]	train-logloss:0.35676	validation-logloss:0.35676
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.22078	validation-logloss:0.22078
#
# [2]	train-logloss:0.17943	validation-logloss:0.17943
#
# [3]	train-logloss:0.11454	validation-logloss:0.11454
#
# [4]	train-logloss:0.07705	validation-logloss:0.07705
#
# [5]	train-logloss:0.05538	validation-logloss:0.05538
#
# [6]	train-logloss:0.04316	validation-logloss:0.04316
#
# [7]	train-logloss:0.03339	validation-logloss:0.03339
#
# [8]	train-logloss:0.02765	validation-logloss:0.02765
#
# [9]	train-logloss:0.02334	validation-logloss:0.02334
#
# [10]	train-logloss:0.01854	validation-logloss:0.01854
#
# [11]	train-logloss:0.01566	validation-logloss:0.01566
#
# [12]	train-logloss:0.01335	validation-logloss:0.01335
#
# [13]	train-logloss:0.01133	validation-logloss:0.01133
#
# [14]	train-logloss:0.00945	validation-logloss:0.00945
#
# [15]	train-logloss:0.00790	validation-logloss:0.00790
#
# [16]	train-logloss:0.00667	validation-logloss:0.00667
#
# [17]	train-logloss:0.00595	validation-logloss:0.00595
#
# [18]	train-logloss:0.00505	validation-logloss:0.00505
#
# [19]	train-logloss:0.00457	validation-logloss:0.00457
#
# [20]	train-logloss:0.00427	validation-logloss:0.00427
#
# [21]	train-logloss:0.00393	validation-logloss:0.00393
#
# [22]	train-logloss:0.00395	validation-logloss:0.00395
#
# [23]	train-logloss:0.00374	validation-logloss:0.00374
#
# [24]	train-logloss:0.00376	validation-logloss:0.00376
#
# [25]	train-logloss:0.00376	validation-logloss:0.00376
#
# [26]	train-logloss:0.00377	validation-logloss:0.00377
#
# [27]	train-logloss:0.00377	validation-logloss:0.00377
#
# [28]	train-logloss:0.00377	validation-logloss:0.00377
#
# [29]	train-logloss:0.00377	validation-logloss:0.00377
#
# [30]	train-logloss:0.00377	validation-logloss:0.00377
#
# [31]	train-logloss:0.00377	validation-logloss:0.00377
#
# [32]	train-logloss:0.00377	validation-logloss:0.00377
#
# [33]	train-logloss:0.00377	validation-logloss:0.00377
#
# Stopping. Best iteration:
# [23]	train-logloss:0.00374	validation-logloss:0.00374
#
#
# 	Score 0.003772956059772696
#
#
# [0]	train-logloss:0.33259	validation-logloss:0.33259
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.19529	validation-logloss:0.19529
#
# [2]	train-logloss:0.11752	validation-logloss:0.11752
#
# [3]	train-logloss:0.07507	validation-logloss:0.07507
#
# [4]	train-logloss:0.04741	validation-logloss:0.04741
#
# [5]	train-logloss:0.03277	validation-logloss:0.03277
#
# [6]	train-logloss:0.02314	validation-logloss:0.02314
#
# [7]	train-logloss:0.01711	validation-logloss:0.01711
#
# [8]	train-logloss:0.01192	validation-logloss:0.01192
#
# [9]	train-logloss:0.00925	validation-logloss:0.00925
#
# [10]	train-logloss:0.00746	validation-logloss:0.00746
#
# [11]	train-logloss:0.00585	validation-logloss:0.00585
#
# [12]	train-logloss:0.00489	validation-logloss:0.00489
#
# [13]	train-logloss:0.00431	validation-logloss:0.00431
#
# [14]	train-logloss:0.00393	validation-logloss:0.00393
#
# [15]	train-logloss:0.00364	validation-logloss:0.00364
#
# [16]	train-logloss:0.00336	validation-logloss:0.00336
#
# [17]	train-logloss:0.00338	validation-logloss:0.00338
#
# [18]	train-logloss:0.00339	validation-logloss:0.00339
#
# [19]	train-logloss:0.00340	validation-logloss:0.00340
#
# [20]	train-logloss:0.00340	validation-logloss:0.00340
#
# [21]	train-logloss:0.00341	validation-logloss:0.00341
#
# [22]	train-logloss:0.00341	validation-logloss:0.00341
#
# [23]	train-logloss:0.00341	validation-logloss:0.00341
#
# [24]	train-logloss:0.00341	validation-logloss:0.00341
#
# [25]	train-logloss:0.00341	validation-logloss:0.00341
#
# [26]	train-logloss:0.00341	validation-logloss:0.00341
#
# Stopping. Best iteration:
# [16]	train-logloss:0.00336	validation-logloss:0.00336
#
#
# 	Score 0.0034091685864259488
#
#
# [0]	train-logloss:0.33357	validation-logloss:0.33357
#
# Multiple eval metrics have been passed: 'validation-logloss' will be used for early stopping.
#
#
# Will train until validation-logloss hasn't improved in 10 rounds.
#
# [1]	train-logloss:0.19136	validation-logloss:0.19136
#
# [2]	train-logloss:0.11590	validation-logloss:0.11590
#
# [3]	train-logloss:0.07425	validation-logloss:0.07425
#
# [4]	train-logloss:0.04728	validation-logloss:0.04728
#
# [5]	train-logloss:0.03273	validation-logloss:0.03273
#
# [6]	train-logloss:0.02453	validation-logloss:0.02453
#
# [7]	train-logloss:0.01809	validation-logloss:0.01809
#
# [8]	train-logloss:0.01259	validation-logloss:0.01259
#
# [9]	train-logloss:0.01040	validation-logloss:0.01040
#
# [10]	train-logloss:0.00831	validation-logloss:0.00831
#
# [11]	train-logloss:0.00726	validation-logloss:0.00726
#
# [12]	train-logloss:0.00639	validation-logloss:0.00639
#
# [13]	train-logloss:0.00562	validation-logloss:0.00562
#
# [14]	train-logloss:0.00514	validation-logloss:0.00514
#
# [15]	train-logloss:0.00464	validation-logloss:0.00464
#
# [16]	train-logloss:0.00464	validation-logloss:0.00464
#
# [17]	train-logloss:0.00464	validation-logloss:0.00464
#
# [18]	train-logloss:0.00464	validation-logloss:0.00464
#
# [19]	train-logloss:0.00464	validation-logloss:0.00464
#
# [20]	train-logloss:0.00464	validation-logloss:0.00464
#
# [21]	train-logloss:0.00464	validation-logloss:0.00464
#
# [22]	train-logloss:0.00464	validation-logloss:0.00464
#
# [23]	train-logloss:0.00464	validation-logloss:0.00464
#
# [24]	train-logloss:0.00464	validation-logloss:0.00464
#
# [25]	train-logloss:0.00464	validation-logloss:0.00464
#
# Stopping. Best iteration:
# [15]	train-logloss:0.00464	validation-logloss:0.00464
#
#
# 	Score 0.00463802822609432
#
#
# 100%|██████████| 25/25 [00:04<00:00,  5.71trial/s, best loss: 0.001774610280059278]
# {'booster': 'gbtree', 'colsample_bylevel': 0.7000000000000001, 'colsample_bynode': 0.8, 'colsample_bytree': 0.9, 'disable_default_eval_metric': 1, 'eta': 0.45, 'eval_metric': 'logloss', 'gamma': 0.8, 'max_delta_step': 10.0, 'max_depth': 1, 'min_child_weight': 1.0, 'objective': 'binary:logistic', 'reg_alpha': 0.0, 'reg_lambda': 1.5, 'sampling_method': 'uniform', 'scale_pos_weight': 332.3333333333333, 'verbosity': 1}
# {'booster': 'gbtree',
#  'colsample_bylevel': 0.7000000000000001,
#  'colsample_bynode': 0.8,
#  'colsample_bytree': 0.9,
#  'disable_default_eval_metric': 1,
#  'eta': 0.45,
#  'eval_metric': 'logloss',
#  'gamma': 0.8,
#  'max_delta_step': 10.0,
#  'max_depth': 1,
#  'min_child_weight': 1.0,
#  'objective': 'binary:logistic',
#  'reg_alpha': 0.0,
#  'reg_lambda': 1.5,
#  'sampling_method': 'uniform',
#  'scale_pos_weight': 332.3333333333333,
#  'verbosity': 1}
